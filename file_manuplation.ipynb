# %%
import cv2
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
import os
from os import listdir
from os.path import isfile, join
import shutil

# %%
mypath = "/home/zodiac/Desktop/rtai/notebooks/data2/positive"
mypath2 = "/home/zodiac/Desktop/rtai/notebooks/data2/positive2"

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
# onlyfiles
# os.path.join(path, "User/Desktop", "file.txt"
mypath
# Out:
# '/home/zodiac/Desktop/rtai/notebooks/data2/negative'

# %%
i=0
for x in onlyfiles:
    i+=1
    op = os.path.join(mypath, x)
    ll = x.split('.')
    newP = os.path.join(mypath2,str(i)+'.'+ll[1])
#     os.rename(op,np)
    shutil.copyfile(op, newP)

# %%
x = "lol"
os.path.join(mypath, x)
# Out:
# '/home/zodiac/Desktop/rtai/notebooks/data2/negative/lol'

# %%
#opencv_annotation --images=/home/zodiac/Desktop/rtai/notebooks/data2/positive --annotations=/home/zodiac/Desktop/rtai/notebooks/data2/ann.txt

# %%
mypath = "/home/zodiac/Desktop/rtai/notebooks/data2/negative"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
#changing dimension of file
path = "/home/zodiac/Desktop/rtai/notebooks/data2/negative2"

# %%
files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
p2 = "/home/zodiac/Desktop/rtai/notebooks/data2/negative"

for x in files:
    img = cv2.imread(os.path.join(path, x))
    newImg = cv2.resize(img, (0,0), fx=0.2, fy=0.2)
    
    newImg = cv2.cvtColor(newImg, cv2.COLOR_BGR2GRAY)
    fpath = os.path.join(p2,x)
    cv2.imwrite(fpath,newImg)
    plt.imshow(newImg)

# %%
ls
# Out:
# ann.txt  car_haar.ipynb  cars.xml  negative/  negative2/  positive/  positive2/

# %%
file = open("ann.txt","r")
Counter = 0
  
# Reading from file
Content = file.read()
CoList = Content.split("\n")
  
files = []

ftor i in CoList:
    kk = i.split("/")
    if kk == ['']:
        break
    lol = kk[8].split(".")
    files.append(lol[0])

# %%
# files

# %%
for x in range(95):
    try:
        index = files.index(str(x))
    except:
        print(x)
# Out:
# 0
# 3
# 19

# %%
ls
# Out:
# 32.jpg  ann.txt         cars.xml   negative2/  positive2/
# 33.jpg  car_haar.ipynb  negative/  positive/

# %%
path = "/home/zodiac/Desktop/rtai/notebooks/data2/positive"

# %%
img2 = cv2.imread('/home/zodiac/Desktop/rtai/notebooks/data2/positive/27.jpg')
plt.imshow(img2)

# %%
img2 = cv2.imread('/home/zodiac/Desktop/rtai/notebooks/data2/positive/27.jpg')
plt.imshow(img2)

print(img2.shape)
#draw rectangle
faces = [[79 ,131 ,113 ,122]]
# faces = [[10, 25, 100, 175]]

img = img2.copy()
for (x,y,w,h) in faces:
    start, end = (x, y), (x+w, y+h)
    cv2.rectangle(img, pt1=start, pt2=end, color=(0,255,0), thickness=3)

plt.imshow(img)
# Out:
# (384, 216, 3)

# %%
mypath = '/home/zodiac/Desktop/rtai/notebooks/data2/negative'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
file1 = open("negative.txt","w")
for x in onlyfiles:
    path = os.path.join(mypath, x)
    file1.write(path)
    file1.write("\n") 
file1.close()

# %%
ls
# Out:
# 32.jpg  car_haar.ipynb  kk.txt     negative2/    negatve.txt  positive2/
# 33.jpg  cars.xml        negative/  negative.txt  positive/    positive.txt
