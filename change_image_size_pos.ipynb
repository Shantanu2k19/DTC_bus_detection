# %%
import os
from os import listdir
from os.path import isfile, join
import shutil

import cv2
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
path1 = "/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive"

# %%
directory =  "/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive"
newP = "/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive_scaledDown"
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        img2 = cv2.imread(f)
#         plt.imshow(img2)
        img2 = img2[420:1500, 0:1080]
        path = os.path.join(newP, filename)
        cv2.imwrite(path,img2)
#/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive

# %%
img = cv2.imread("/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive/frameI285.jpg")

# %%
img.shape
# Out:
# (1920, 1080, 3)

# %%
img2 = img.copy()
img2 = img2[420:1500, 0:1080]
# img2 = cv2.resize(img2, (0, 0), fx = 0.093, fy = 0.093)
# img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# cv2.imwrite(newP,img2)

# %%
img2.shape
# Out:
# (1080, 1080, 3)

# %%
newP = "/home/zodiac/Desktop/rtai/notebooks/data2/newData/lol.jpg"
cv2.imwrite(newP,img2)
# Out:
# True

# %%
img = cv2.imread("/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive/frameD270.jpg")

# %%
plt.imshow(img)

# %%
lol="/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive"
newP = "/home/zodiac/Desktop/rtai/notebooks/data2/newData/positive_scaledDown"

# %%
nam = "frameE60.jpg"
img2 = cv2.imread(os.path.join(lol,nam))
# img2 = img2[520:1600, 0:1080]
plt.imshow(img2)

# %%
path = os.path.join(newP, nam)
cv2.imwrite(path,img2)
# Out:
# True

# %%
import json
 
# Opening JSON file
f = open('/home/zodiac/Desktop/lol/annotations.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
# Iterating through the json
# list
for i in data:
    print(i)
    print(data[i])
    break
# Closing file
f.close()
# Out:
# ___sa_version___
# 1.0.0
